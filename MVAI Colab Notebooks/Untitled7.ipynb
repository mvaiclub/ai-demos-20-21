# %%
# Dataset: https://www.kaggle.com/sakshigoyal7/credit-card-customers

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
#get data
data=pd.read_csv('BankChurners.csv')

#quick look at data
data.head()
print(data.shape)
# Out:
# (10127, 23)

# %%
#remove unnecessary  two columns
data.drop(columns=data.columns[-2:], inplace=True)
data.drop(columns=data.columns[0],axis=1, inplace=True)
data.head()
# Out:
#       Attrition_Flag  Customer_Age  ... Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0  Existing Customer            45  ...               1.625                  0.061
# 1  Existing Customer            49  ...               3.714                  0.105
# 2  Existing Customer            51  ...               2.333                  0.000
# 3  Existing Customer            40  ...               2.333                  0.760
# 4  Existing Customer            40  ...               2.500                  0.000
#
# [5 rows x 20 columns]

# %%
# Finding all the categorical columns from the data
categorical = data.select_dtypes(exclude=['int64','float64']).columns
for i in categorical:
    data[i]=pd.factorize(data[i])[0]
data.head()

#normalize data
for col in data:
  data[col] = data[col]/data[col].max()
data.head()
# Out:
#    Attrition_Flag  Customer_Age  ...  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             0.0      0.616438  ...             0.437534               0.061061
# 1             0.0      0.671233  ...             1.000000               0.105105
# 2             0.0      0.698630  ...             0.628164               0.000000
# 3             0.0      0.547945  ...             0.628164               0.760761
# 4             0.0      0.547945  ...             0.673129               0.000000
#
# [5 rows x 20 columns]

# %%
#divide input and output
y=data['Attrition_Flag'].values
x=data.drop('Attrition_Flag',axis=1).values

#train test split
xtrain, xtest, ytrain, ytest = train_test_split( x, y, test_size=0.2, random_state=20,shuffle=True)

# %%
k = tf.keras.layers
model = tf.keras.Sequential()

model.add(k.Dense(100, activation = 'relu'))
model.add(k.Dense(1, activation = 'sigmoid'))

model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ['accuracy'])
model.fit(xtrain, ytrain, epochs = 50)

print(model.evaluate(xtest, ytest)[1])
# Out:
# Epoch 1/50
# 254/254 [==============================] - 1s 1ms/step - loss: 0.4498 - accuracy: 0.8255
# Epoch 2/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.3242 - accuracy: 0.8705
# Epoch 3/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2905 - accuracy: 0.8875
# Epoch 4/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2706 - accuracy: 0.8939
# Epoch 5/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2685 - accuracy: 0.8940
# Epoch 6/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2482 - accuracy: 0.9036
# Epoch 7/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2456 - accuracy: 0.9051
# Epoch 8/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2245 - accuracy: 0.9125
# Epoch 9/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2291 - accuracy: 0.9094
# Epoch 10/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2303 - accuracy: 0.9074
# Epoch 11/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2190 - accuracy: 0.9106
# Epoch 12/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2201 - accuracy: 0.9134
# Epoch 13/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2093 - accuracy: 0.9120
# Epoch 14/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2153 - accuracy: 0.9160
# Epoch 15/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2014 - accuracy: 0.9203
# Epoch 16/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1960 - accuracy: 0.9196
# Epoch 17/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2046 - accuracy: 0.9178
# Epoch 18/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.2010 - accuracy: 0.9214
# Epoch 19/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1981 - accuracy: 0.9212
# Epoch 20/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1971 - accuracy: 0.9176
# Epoch 21/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1887 - accuracy: 0.9249
# Epoch 22/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.9164
# Epoch 23/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1862 - accuracy: 0.9291
# Epoch 24/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1867 - accuracy: 0.9235
# Epoch 25/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1855 - accuracy: 0.9215
# Epoch 26/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1777 - accuracy: 0.9279
# Epoch 27/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1741 - accuracy: 0.9317
# Epoch 28/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1757 - accuracy: 0.9320
# Epoch 29/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1629 - accuracy: 0.9385
# Epoch 30/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1689 - accuracy: 0.9319
# Epoch 31/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1795 - accuracy: 0.9287
# Epoch 32/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1795 - accuracy: 0.9288
# Epoch 33/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1743 - accuracy: 0.9316
# Epoch 34/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1664 - accuracy: 0.9341
# Epoch 35/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1733 - accuracy: 0.9290
# Epoch 36/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1653 - accuracy: 0.9354
# Epoch 37/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1672 - accuracy: 0.9319
# Epoch 38/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1626 - accuracy: 0.9324
# Epoch 39/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1592 - accuracy: 0.9411
# Epoch 40/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1661 - accuracy: 0.9340
# Epoch 41/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1633 - accuracy: 0.9337
# Epoch 42/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1568 - accuracy: 0.9401
# Epoch 43/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1605 - accuracy: 0.9356
# Epoch 44/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1605 - accuracy: 0.9362
# Epoch 45/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1558 - accuracy: 0.9367
# Epoch 46/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1695 - accuracy: 0.9364
# Epoch 47/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1568 - accuracy: 0.9391
# Epoch 48/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1619 - accuracy: 0.9334
# Epoch 49/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1548 - accuracy: 0.9343
# Epoch 50/50
# 254/254 [==============================] - 0s 1ms/step - loss: 0.1541 - accuracy: 0.9386
# 64/64 [==============================] - 0s 1ms/step - loss: 0.1544 - accuracy: 0.9373
# 0.9373149275779724
