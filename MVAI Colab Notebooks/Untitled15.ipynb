# %%
import numpy as mp
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import cv2
import os
from os import listdir
import string

# %%
data_path = '/content/data'
images = []
symbols = string.ascii_lowercase + "0123456789"



image_paths = []
for img in os.listdir(data_path):
  image_paths.append(img)

texts = np.zeros((5, len(image_paths), len(symbols)))
i = 0
for img in image_paths:
  image = cv2.imread((data_path +img), cv2.IMREAD_GRAYSCALE)
  images.append(image)
  text = img.split('.')[0]
  encoded_text = np.zeros((5, len(symbols)))
  #   [dog, cat, bike]
  #cat: [0, 1, 0]
  #   [a, b, c, ...]
  #c: [0, 0, 1, ...]
  for j, l in enumerate(text):
      index = symbols.find(l)
      encoded_text[j, index] = 1
  texts[:, i] = encoded_text
  i+=1

images = np.array(images)
print(images.shape)
images = images/255.0

xtrain, ytrain = images[:970], texts[:, :970]
xtest, ytest = images[970:], texts[:, 970: ]
# Out:
# (1072,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-c737ec4b049a> in <module>()
#      28 images = np.array(images)
#      29 print(images.shape)
# ---> 30 images = images/255.0
#      31
#      32 xtrain, ytrain = images[:970], texts[:, :970]
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'float'
